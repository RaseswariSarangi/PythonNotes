# %%
from PIL import Image

# %%
word_matrix=Image.open('word_matrix.png')

# %%
new_word_matrix=word_matrix.convert('RGB')

# %%
new_word_matrix.save('new_word_matrix.jpg')

# %%
word_matrix=Image.open('new_word_matrix.jpg')

# %%
word_matrix
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1015x559 at 0x1CE981AF6A0>

# %%
mask=Image.open('mask.png')

# %%
new_mask=mask.convert('RGB')

# %%
new_mask.save('newmask.jpg')

# %%
mask=Image.open('newmask.jpg')

# %%
mask
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=505x251 at 0x1CE981AF5B0>

# %%
word_matrix.size
# Out:
# (1015, 559)

# %%
new_size_mask=mask.resize((1015,559))

# %%
new_size_mask
# Out:
# <PIL.Image.Image image mode=RGB size=1015x559 at 0x1CE97C10730>

# %%
new_size_mask.putalpha(100)

# %%
new_size_mask
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559 at 0x1CE97C10730>

# %%
word_matrix.paste(im=new_size_mask,box=(0,0),mask=new_size_mask)

# %%
word_matrix
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1015x559 at 0x1CE981AF6A0>

# %%
word_matrix.save('word_matrix_solution.jpg')

# %%
solution=Image.open('word_matrix_solution.jpg')

# %%
solution
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1015x559 at 0x1CE97C442E0>
